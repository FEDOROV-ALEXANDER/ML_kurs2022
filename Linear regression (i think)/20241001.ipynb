# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def f(x, A=10, a=2, W=0.2, w=10):
    return A*np.sin(W*x)+a*np.sin(w*x)

x = np.linspace(0, 4, 1000)
y = f(x) + np.random.rand(len(x))*2
plt.figure()
plt.plot(x,y)
plt.show()

# %%
df = pd.DataFrame({'x' : x, 'y' : y})
df
# Out:
#             x          y
# 0    0.000000   0.760109
# 1    0.004004   2.076752
# 2    0.008008   2.127375
# 3    0.012012   0.907840
# 4    0.016016   1.046244
# ..        ...        ...
# 995  3.983984   9.564108
# 996  3.987988  10.280269
# 997  3.991992  10.701618
# 998  3.995996  10.682727
# 999  4.000000   9.015842
#
# [1000 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(df[['x']], df['y'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([1.81029337])

# %%
reg.intercept_
# Out:
# 1.2186610415816572

# %%
plt.figure()
plt.plot(x, y)
plt.plot(x, reg.coef_*x + reg.intercept_)
plt.show()

# %%
for i in range(15):
    df[f'sin{i}x'] = np.sin(i*x)
df.head()
# Out:
#           x         y  sin0x     sin1x     sin2x     sin3x     sin4x  \
# 0  0.000000  0.760109    0.0  0.000000  0.000000  0.000000  0.000000
# 1  0.004004  2.076752    0.0  0.004004  0.008008  0.012012  0.016015
# 2  0.008008  2.127375    0.0  0.008008  0.016015  0.024022  0.032027
# 3  0.012012  0.907840    0.0  0.012012  0.024022  0.036028  0.048030
# 4  0.016016  1.046244    0.0  0.016015  0.032027  0.048030  0.064020
#
#       sin5x     sin6x     sin7x     sin8x     sin9x    sin10x    sin11x  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.020019  0.024022  0.028024  0.032027  0.036028  0.040029  0.044030
# 2  0.040029  0.048030  0.056027  0.064020  0.072010  0.079995  0.087974
# 3  0.060024  0.072010  0.083985  0.095948  0.107898  0.119831  0.131748
# 4  0.079995  0.095948  0.111877  0.127778  0.143646  0.159476  0.175266
#
#      sin12x    sin13x    sin14x
# 0  0.000000  0.000000  0.000000
# 1  0.048030  0.052029  0.056027
# 2  0.095948  0.103916  0.111877
# 3  0.143646  0.155522  0.167377
# 4  0.191011  0.206707  0.222350

# %%
Y = df['y']
X = df.drop(columns=['y'])
reg = LinearRegression()
reg.fit(X, Y)
print(reg.coef_, reg.intercept_)
# Out:
# [ 1.88756352e+00  1.05471187e-15  1.93793813e-01 -4.92670932e-03
#   2.18188916e-02  2.54552295e-02 -4.36487295e-02  4.95911256e-02
#   4.31205405e-02  3.75885701e-02  1.63691596e-03  1.99783424e+00
#  -2.50541483e-02 -1.72139609e-02 -1.40728473e-02 -5.23961595e-02] 0.8954628574622392

# %%
plt.figure()
plt.plot(x, y)
plt.plot(x, reg.predict(X))
plt.show()

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3)

# %%
X_train
# Out:
#             x  sin0x     sin1x     sin2x     sin3x     sin4x     sin5x  \
# 988  3.955956    0.0 -0.727289  0.998323 -0.643072 -0.115602  0.801754
# 202  0.808809    0.0  0.723465  0.998904  0.655743 -0.093506 -0.784848
# 231  0.924925    0.0  0.798576  0.961317  0.358647 -0.529581 -0.996151
# 428  1.713714    0.0  0.989805 -0.281958 -0.909485  0.541037  0.755364
#         6.07118338,  9.45260923,  7.49536617,  7.91670706,  5.70338678,
#         9.07857767,  2.45372183,  0.07421317,  9.05777433,  2.33113127,
#         3.28692967,  5.68983459,  2.80570836,  0.24488955,  3.89520563,
#         3.87542842,  3.17484208,  6.12705703,  9.11590129,  6.06631881,
#         5.88111234,  3.43245254,  3.06535919,  4.67725896,  8.33107608,
#         1.02575353,  0.18232649,  5.58964965,  6.661852  ,  4.29125097,
#         8.0405727 , -0.16747407,  4.54479246,  1.1980777 ,  4.18266108,
#         8.87010538,  3.88517209,  1.72362433,  2.4250769 ,  3.48272658,
#         5.58819926,  3.15060213,  7.48502082,  7.02460841,  4.81455514,
#         5.63554026,  4.83815223,  4.77939694,  5.61294377,  5.5097891 ,
#         6.63763101,  2.50578308,  5.52004064,  6.92150799,  4.73972229,
#         5.44069804,  0.56756846,  6.76007184,  5.76593406,  2.02991776,
#        10.10770223,  3.98471607,  3.06435763,  5.56658837,  5.72604018,
#         2.92956892,  8.40385558,  5.99987407,  5.09611698, -0.13597239,
#         1.18901877,  3.10892619,  6.83787135,  6.946955  ,  8.76520235,
#         4.03302636,  5.02706022,  1.24075655,  2.1745132 ,  3.72593519,
#         2.77354201,  4.82920162,  1.51030242,  1.3678593 ,  1.54931638,
#         8.20636553, 10.16244347,  6.18021924,  3.49373649,  6.46150053,
#         4.92161582,  5.77667562,  0.45217617,  3.89367605,  4.97075243,
#         5.63493125,  2.13715228,  1.95159368,  5.84861861,  8.78458525,
#         6.85802614, -0.07258091,  2.35538536,  5.14226933,  5.64195225,
#         8.84782245,  4.17391586,  4.61125445,  7.86071314,  9.08624445,
#         4.48930453,  3.49917738,  5.62539558,  4.4388685 ,  4.10358401,
#         7.15928529,  2.67916695,  5.59015714,  2.30277396,  3.66019776,
#         1.65444611,  1.22046814,  1.25813335,  1.44571009,  3.10159309,
#         6.08893093,  5.57762853,  9.01056894,  5.18273044,  7.69750602,
#         7.82800764,  0.39527241,  5.83997174,  9.51831016,  1.35307974,
#         1.41834192,  3.87529282,  3.61760029,  1.01570644,  2.95601381,
#         2.38428235,  2.76901421,  8.0249618 , 10.08167617, -0.15816454,
#         3.00034574,  4.53246839,  6.51485651,  2.0702254 ,  2.35989555,
#         1.28185234,  5.24049611,  5.25759359,  7.66072292,  7.19734937,
#         4.22476763,  6.68998063, -0.02637211, 10.01940154,  0.65198424,
#         3.13065972,  3.77655181,  6.79180451,  2.28845559,  9.64191312,
#         5.32923775,  4.06796861,  5.28142882,  0.23119799,  3.42563305])

# %%
y_test
# Out:
# 797    8.879792
# 936    6.824480
# 660    7.032926
# 563    3.961188
# 63     2.080139
#          ...
# 479    5.945602
# 182    4.733632
# 551    5.827835
# 134    0.334285
# 173    3.656551
# Name: y, Length: 300, dtype: float64

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
print(mse(y_test, y_pred))
print(mae(y_test, y_pred))
# Out:
# 0.3454964357450359
# 0.5033593711023375

# %%
y_error = y_test - y_pred
plt.figure()
plt.hist(y_error, bins = 30)
plt.show()
